# %% [markdown]
# <a href="https://colab.research.google.com/github/TmTrojcak/Computational_Physics/blob/main/Binding_Energy_vs_Atomic_Mass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the data
file_path = "/binding.txt"
data = pd.read_csv(file_path, delim_whitespace=True, header=None, names=["Atomic Number", "Element", "Binding Energy", "Mass Number"])
# Out:
# <ipython-input-2-fcb3862bf033>:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   data = pd.read_csv(file_path, delim_whitespace=True, header=None, names=["Atomic Number", "Element", "Binding Energy", "Mass Number"])

# %%
data
# Out:
#      Atomic Number Element  Binding Energy  Mass Number
# 0                1       H           0.000            1
# 1                2       H           1.112            2
# 2                3       H           2.827            3
# 3                3      He           2.573            3
# 4                4      He           7.074            4
# ..             ...     ...             ...          ...
# 139            227      Ac           7.651          227
# 140            231      Pa           7.618          231
# 141            232      Th           7.615          232
# 142            235       U           7.591          235
# 143            238       U           7.570          238
#
# [144 rows x 4 columns]

# %%
# Extract relevant columns for plotting
mass_numbers = data["Mass Number"]
binding_energies = data["Binding Energy"]

# %%
# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(mass_numbers, binding_energies, marker='o', linestyle='-', color='blue')

# Add labels and title
plt.title('Binding Energy per Nucleon vs. Mass Number', fontsize=14)
plt.xlabel('Mass Number', fontsize=12)
plt.ylabel('Binding Energy per Nucleon (MeV)', fontsize=12)

# Show gridlines
plt.grid()

# Display the plot
plt.show()
